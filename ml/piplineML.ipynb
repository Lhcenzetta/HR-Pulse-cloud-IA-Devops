# %% [markdown]
# load the data

# %%
import pandas as pd
from dotenv import load_dotenv
import os
load_dotenv()

path_csv = os.getenv("path_clean_data")

df = pd.read_csv(path_csv)
df.head(5)
# Out:
#    index          job_title               salary_estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      job_description  rating  \
# 0  Description  The Senior Data Scientist is resp...     3.1
# 1  Secure our Nation, Ignite your Future  Join th...     4.2
# 2  Overview   Analysis Group is one of the larges...     3.8
# 3  JOB DESCRIPTION:  Do you have a passion for Da...     3.5
# 4  Data Scientist Affinity Solutions / Marketing ...     2.9
#
#              company_name       location            headquarters  \
# 0         Healthfirst 3.1   New York, NY            New York, NY
# 1             ManTech 4.2  Chantilly, VA             Herndon, VA
# ...

# %%
df['rating'] = df['rating'].apply(lambda x: 0 if x == -1 else x)

# %%
df['age'] = df['founded'].apply(lambda x: 2026 - x if x > 0 else 0)

# %%
categorical_cols = ['size', 'type_of_ownership', 'industry', 'sector']
for col in categorical_cols:
    df[col] = df[col].replace(['-1', -1], 'Unknown')

# %%
X = df[['rating', 'age', 'size', 'type_of_ownership', 'industry', 'sector']]
y = df['salary_clean']

# %%
# mlb = MultiLabelBinarizer()
#     skills_encoded = mlb.fit_transform(df['skills_extracted'])
#     skills_df = pd.DataFrame(skills_encoded, columns=mlb.classes_, index=df.index)

#     # Sélection des features : On combine les skills et les infos entreprises
#     X = pd.concat([df[['Rating']], skills_df], axis=1)
#     y = df['salary_avg']

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ], remainder='passthrough')

model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(n_estimators=100, random_state=42))
])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/34/r9gx_24s3cn901gzyz1dpgm80000gn/T/ipykernel_1190/180087699.py in ?()
# ----> 1 model.fit(X_train, y_train)
#
# ~/Desktop/HR-Pulse-cloud-IA-Devops/.venv/lib/python3.13/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1332                 skip_parameter_validation=(
#    1333                     prefer_skip_nested_validation or global_skip_validation
#    1334                 )
#    1335             ):
# -> 1336                 return fit_method(estimator, *args, **kwargs)
#
# ~/Desktop/HR-Pulse-cloud-IA-Devops/.venv/lib/python3.13/site-packages/sklearn/ensemble/_gb.py in ?(self, X, y, sample_weight, monitor)
#     662         # Check input
#     663         # Since check_array converts both X and y to the same dtype, but the
# ...

# %%
# from sklearn.metrics import mean_absolute_error
# print(f"MAE : {mean_absolute_error(y_test, model.predict(X_test)):.2f} K$")
# accuracy = model.score(X_test, y_test)
# print(f"R² Score: {accuracy:.2f}")

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/34/r9gx_24s3cn901gzyz1dpgm80000gn/T/ipykernel_1190/616623703.py in ?()
#       1 # from sklearn.base import r2_score
#       2 from sklearn.ensemble import GradientBoostingRegressor
#       3 model = GradientBoostingRegressor(n_estimators=200, learning_rate=0.05)
# ----> 4 model.fit(X_train, y_train)
#       5
#       6 y_pred = model.predict(X_test)
#       7 print(f"Nouveau MAE : {mean_absolute_error(y_test, y_pred):.2f} K$")
#
# ~/Desktop/HR-Pulse-cloud-IA-Devops/.venv/lib/python3.13/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1332                 skip_parameter_validation=(
#    1333                     prefer_skip_nested_validation or global_skip_validation
#    1334                 )
#    1335             ):
# -> 1336                 return fit_method(estimator, *args, **kwargs)
#
# ...
